# %%
import azureml.core 
print(azureml.core.VERSION) 
from azureml.core import Workspace 
ws = Workspace.from_config()
ws.get_details()
# Out:
# 1.57.0
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code CM4KPQTWE to authenticate.
# Interactive authentication successfully completed.
# {'id': '/subscriptions/5f7e7551-1c5d-42a7-9cdd-7582134d0f5f/resourceGroups/iiot-book2-resource/providers/Microsoft.MachineLearningServices/workspaces/iiot-book2-ml-workspace',
#  'name': 'iiot-book2-ml-workspace',
#  'identity': {'principal_id': '4cd35736-b2a7-4978-9c70-c5155633054e',
#   'tenant_id': 'cfb4f1d4-a84e-4e91-9df0-435862090a34',
#   'type': 'SystemAssigned'},
#  'location': 'eastus2',
#  'type': 'Microsoft.MachineLearningServices/workspaces',
#  'tags': {},
#  'sku': 'Basic',
#  'workspaceid': '1352f7c8-4b9b-4670-9827-bb2f337ec25b',
#  'sdkTelemetryAppInsightsKey': 'e1f7b545-6243-4abf-ba76-c5691d2edb62',
#  'description': '',
#  'friendlyName': 'iiot-book2-ml-workspace',
#  'creationTime': '2024-08-13T10:36:53.1780731Z',
#  'keyVault': '/subscriptions/5f7e7551-1c5d-42a7-9cdd-7582134d0f5f/resourceGroups/iiot-book2-resource/providers/Microsoft.Keyvault/vaults/iiotbook2mlwor9593714222',
#  'applicationInsights': '/subscriptions/5f7e7551-1c5d-42a7-9cdd-7582134d0f5f/resourceGroups/iiot-book2-resource/providers/Microsoft.insights/components/iiotbook2mlwor1740702465',
#  'storageAccount': '/subscriptions/5f7e7551-1c5d-42a7-9cdd-7582134d0f5f/resourceGroups/iiot-book2-resource/providers/Microsoft.Storage/storageAccounts/iiotbook2storage',
#  'hbiWorkspace': False,
#  'provisioningState': 'Deleting',
#  'discoveryUrl': 'https://eastus2.api.azureml.ms/discovery',
#  'notebookInfo': {'fqdn': 'ml-iiot-book2-ml-w-eastus2-1352f7c8-4b9b-4670-9827-bb2f337ec25b.eastus2.notebooks.azure.net',
#   'resource_id': '38d84e0b851d41cba930112a81a95626'},
#  'v1LegacyMode': False}

# %%
import pandas as pd 

import matplotlib.pyplot as plt 
import numpy as np 


def wind_turbine_model(x): 
    # cut-in speed vs cut-out speed 
    if x<4.5 or x>21.5: 
        return 0.0 
    # standard operability 
    return 376.936 - 195.8161*x + 33.75734*x**2 - 2.212492*x**3 + 0.06309095*x**4 - 0.0006533647*x**5 

reference_power = [wind_turbine_model(x) for x in range(0,30)] 

# show data and reference 
fig, ax = plt.subplots() 
ax.plot(reference_power,'k') 
ax.set_xlabel('wind speed (m/s)') 
ax.set_ylabel('power (kW)') 
plt.show()

# %%
from azureml.core import Experiment  

# create a new experiment  
exp = Experiment(workspace=ws, name='wind-turbine-experiment')  

# start a run 
run = exp.start_logging()
run.log_list('Wind Turbine Model', reference_power) # log a list of values  

# finish the run  
run.complete()  

print(run.get_portal_url())
# Out:
# ---------------------------------------------------------------------------
# ExperimentExecutionException              Traceback (most recent call last)
# Input In [3], in <cell line: 7>()
#       4 exp = Experiment(workspace=ws, name='wind-turbine-experiment-1')
#       6 # start a run
# ----> 7 run = exp.start_logging()
#       8 run.log_list('Wind Turbine Model', reference_power) # log a list of values
#      10 # finish the run
#
# File /opt/conda/lib/python3.10/site-packages/azureml/core/experiment.py:279, in Experiment.start_logging(self, *args, **kwargs)
#     244 """Start an interactive logging session and create an interactive run in the specified experiment.
#     245
#     246 .. remarks::
#    (...)
#     276 :rtype: azureml.core.Run
#     277 """
#     278 from azureml.core.run import Run
# --> 279 return Run._start_logging(self, *args, _parent_logger=self._logger, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/azureml/core/run.py:615, in Run._start_logging(experiment, name, run_id, outputs, snapshot_directory, **kwargs)
#     613 if snapshot_directory:
#     614     try:
# --> 615         run.take_snapshot(snapshot_directory)
#     616     except SnapshotException as snapshot_ex:
#     617         error_msg = "Failed to take a snapshot of {}. Pass snapshot_directory=None to start_logging " \
#     618                     "to skip taking a snapshot of the given directory.".format(snapshot_directory)
#
# File /opt/conda/lib/python3.10/site-packages/azureml/core/run.py:2207, in Run.take_snapshot(self, file_or_folder_path)
#    2189 def take_snapshot(self, file_or_folder_path):
#    2190     r"""Save a snapshot of the input file or folder.
#    2191
#    2192     .. remarks::
#    (...)
#    2205     :rtype: str
#    2206     """
# -> 2207     return self._client.take_snapshot(file_or_folder_path)
#
# File /opt/conda/lib/python3.10/site-packages/azureml/_run_impl/run_history_facade.py:704, in RunHistoryFacade.take_snapshot(self, file_or_folder_path, _raise_on_validation_failure)
#     701     raise SnapshotException("Cannot take snapshot as the run already has one: {}".format(existing_snapshot))
#     703 with self._log_context("TakingSnapshot") as slcx:
# --> 704     snapshot_id = self.snapshots.create_snapshot(
#     705         file_or_folder_path,
#     706         raise_on_validation_failure=_raise_on_validation_failure)
#     708     slcx.debug("Created snapshot {}".format(snapshot_id))
#     709     self.add_properties({
#     710         PropertyKeys.SNAPSHOT_ID: snapshot_id
#     711     })
#
# File /opt/conda/lib/python3.10/site-packages/azureml/_restclient/snapshots_client.py:91, in SnapshotsClient.create_snapshot(self, file_or_folder_path, retry_on_failure, raise_on_validation_failure)
#      89 # Get the previous snapshot for this project
#      90 try:
# ---> 91     parent_root, parent_snapshot_id = self._cache.get_latest_snapshot()
#      92 except json.decoder.JSONDecodeError:
#      93     # Removing the cache file if found corrupted
#      94     self._cache.remove_latest()
#
# File /opt/conda/lib/python3.10/site-packages/azureml/_base_sdk_common/project_snapshot_cache.py:48, in ContentSnapshotCache.get_latest_snapshot(self)
#      46 if response.status_code >= 400:
#      47     from azureml._base_sdk_common.common import get_http_exception_response_string
# ---> 48     raise ExperimentExecutionException(get_http_exception_response_string(response))
#      50 response_data = response.content.decode('utf-8')
#      51 snapshot_dict = json.loads(response_data)
#
# ExperimentExecutionException: ExperimentExecutionException:
# 	Message: {
#     "error_details": {
#         "componentName": "project",
#         "correlation": {
#             "operation": "00767d971a3555719d01ccb72b6cb8ca",
#             "request": "bbaf428ad4733d64"
#         },
#         "environment": "eastus2",
#         "error": {
#             "code": "UserError",
#             "message": "Please make sure workspace msi has permission to the workspace keyvault and workspace keyvault exists"
#         },
#         "location": "eastus2",
#         "statusCode": 400,
#         "time": "2024-08-13T15:51:27.9702947+00:00"
#     },
#     "status_code": 400,
#     "url": "https://eastus2.experiments.azureml.net/content/v1.0/subscriptions/5f7e7551-1c5d-42a7-9cdd-7582134d0f5f/resourceGroups/iiot-book2-resource/providers/Microsoft.MachineLearningServices/workspaces/iiot-book2-ml-workspace/snapshots/latest/metadata"
# }
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "{\n    \"error_details\": {\n        \"componentName\": \"project\",\n        \"correlation\": {\n            \"operation\": \"00767d971a3555719d01ccb72b6cb8ca\",\n            \"request\": \"bbaf428ad4733d64\"\n        },\n        \"environment\": \"eastus2\",\n        \"error\": {\n            \"code\": \"UserError\",\n            \"message\": \"Please make sure workspace msi has permission to the workspace keyvault and workspace keyvault exists\"\n        },\n        \"location\": \"eastus2\",\n        \"statusCode\": 400,\n        \"time\": \"2024-08-13T15:51:27.9702947+00:00\"\n    },\n    \"status_code\": 400,\n    \"url\": \"https://eastus2.experiments.azureml.net/content/v1.0/subscriptions/5f7e7551-1c5d-42a7-9cdd-7582134d0f5f/resourceGroups/iiot-book2-resource/providers/Microsoft.MachineLearningServices/workspaces/iiot-book2-ml-workspace/snapshots/latest/metadata\"\n}"
#     }
# }

# %%
# clean the workspace 
ws.delete(delete_dependent_resources=True)
